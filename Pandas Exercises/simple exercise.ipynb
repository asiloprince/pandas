# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ** Read economic_indicators.csv as a dataframe called eco.**

# %%
eco = pd.read_csv('dataset/economic_indicators.csv')

# %% [markdown]
# ** Check the head of the DataFrame. **

# %%
eco.head()
# Out:
#   Country Name Country Code
# 0  Philippines          PHL  \
# 1  Philippines          PHL
# 2  Philippines          PHL
# 3  Philippines          PHL
# 4      Myanmar          MMR
#
#                                          Series Name        Series Code
# 0                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG  \
# 1                   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG
# 2                                  Population, total        SP.POP.TOTL
# 3  Unemployment, total (% of total labor force) (...     SL.UEM.TOTL.ZS
# 4                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
#
#            2000          2001          2002          2003          2004
# 0  4.382505e+00  3.049232e+00  3.716255e+00  5.086911e+00  6.569229e+00  \
# 1  2.094019e+00  8.907429e-01  1.598835e+00  2.987190e+00  4.472465e+00
# 2  7.795822e+07  7.962609e+07  8.128557e+07  8.294284e+07  8.460750e+07
# ...

# %% [markdown]
# ** Use the .info() method to find out how many entries there are.**

# %%
eco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  42 non-null     object
#  1   Country Code  40 non-null     object
#  2   Series Name   40 non-null     object
#  3   Series Code   40 non-null     object
#  4   2000          40 non-null     float64
#  5   2001          40 non-null     float64
#  6   2002          40 non-null     float64
#  7   2003          40 non-null     float64
#  8   2004          40 non-null     float64
#  9   2005          40 non-null     float64
#  10  2006          40 non-null     float64
#  11  2007          40 non-null     float64
#  12  2008          40 non-null     float64
#  13  2009          40 non-null     float64
#  14  2010          40 non-null     float64
#  15  2011          40 non-null     float64
#  16  2012          40 non-null     float64
# ...

# %%
eco.describe().transpose()
# Out:
#       count          mean           std        min       25%       50%
# 2000   40.0  1.311234e+07  3.857681e+07   0.654000  3.419540  5.939391  \
# 2001   40.0  1.330251e+07  3.912295e+07  -3.703666  2.420274  3.904535
# 2002   40.0  1.348949e+07  3.966434e+07   0.663000  3.378492  5.312364
# 2003   40.0  1.367213e+07  4.020091e+07   0.656000  3.494425  5.998501
# 2004   40.0  1.385380e+07  4.072205e+07  -1.284601  4.135765  6.507109
# 2005   40.0  1.403525e+07  4.124226e+07  -1.325051  3.492515  5.866286
# 2006   40.0  1.421917e+07  4.177698e+07   0.661000  4.116777  6.078083
# 2007   40.0  1.440676e+07  4.232193e+07  -1.416168  3.982962  6.321904
# 2008   40.0  1.459530e+07  4.286992e+07  -3.423746  1.911121  4.885207
# 2009   40.0  1.478054e+07  4.341615e+07  -3.443343  0.117639  4.089253
# 2010   40.0  1.496507e+07  4.396380e+07   0.620000  4.352612  6.680980
# 2011   40.0  1.515134e+07  4.451895e+07   0.190947  3.455000  5.409044
# ...

# %% [markdown]
# ** get gdp per capita growth(annual%) by its series code.**

# %%
eco[eco['Series Code'] == 'NY.GDP.PCAP.KD.ZG']
# Out:
#          Country Name Country Code                       Series Name
# 1         Philippines          PHL  GDP per capita growth (annual %)  \
# 5             Myanmar          MMR  GDP per capita growth (annual %)
# 9             Lao PDR          LAO  GDP per capita growth (annual %)
# 13           Cambodia          KHM  GDP per capita growth (annual %)
# 17  Brunei Darussalam          BRN  GDP per capita growth (annual %)
# 21          Indonesia          IDN  GDP per capita growth (annual %)
# 25           Malaysia          MYS  GDP per capita growth (annual %)
# 29          Singapore          SGP  GDP per capita growth (annual %)
# 33           Thailand          THA  GDP per capita growth (annual %)
# 37            Vietnam          VNM  GDP per capita growth (annual %)
#
#           Series Code       2000       2001       2002       2003       2004
# 1   NY.GDP.PCAP.KD.ZG   2.094019   0.890743   1.598835   2.987190   4.472465  \
# ...

# %% [markdown]
# **Copy the dataframe and extract only the population data.**

# %%
tp = eco[eco['Series Code'] == 'SP.POP.TOTL'].copy()
tp = tp.copy()
tp.reset_index(drop=True, inplace=True)

# %%
tp
# Out:
#         Country Name Country Code        Series Name  Series Code
# 0        Philippines          PHL  Population, total  SP.POP.TOTL  \
# 1            Myanmar          MMR  Population, total  SP.POP.TOTL
# 2            Lao PDR          LAO  Population, total  SP.POP.TOTL
# 3           Cambodia          KHM  Population, total  SP.POP.TOTL
# 4  Brunei Darussalam          BRN  Population, total  SP.POP.TOTL
# 5          Indonesia          IDN  Population, total  SP.POP.TOTL
# 6           Malaysia          MYS  Population, total  SP.POP.TOTL
# 7          Singapore          SGP  Population, total  SP.POP.TOTL
# 8           Thailand          THA  Population, total  SP.POP.TOTL
# 9            Vietnam          VNM  Population, total  SP.POP.TOTL
#
#           2000         2001         2002         2003         2004
# 0   77958223.0   79626086.0   81285572.0   82942837.0   84607501.0  \
# 1   45538332.0   46014826.0   46480230.0   46924293.0   47338446.0
# ...

# %% [markdown]
# **what is total population of asean country in year 2020**

# %%
total_population_2020 = tp['2020'].sum()

# %%
total_population_2020
# Out:
# 668640278.0

# %%
tp[['Country Name','2020']]
# Out:
#         Country Name         2020
# 0        Philippines  112190977.0
# 1            Myanmar   53423198.0
# 2            Lao PDR    7319399.0
# 3           Cambodia   16396860.0
# 4  Brunei Darussalam     441725.0
# 5          Indonesia  271857970.0
# 6           Malaysia   33199993.0
# 7          Singapore    5685807.0
# 8           Thailand   71475664.0
# 9            Vietnam   96648685.0

# %%
tp[['Country Name','2020']].min()
# Out:
# Country Name    Brunei Darussalam
# 2020                     441725.0
# dtype: object

# %%
tp[['Country Name','2020']].max()
# Out:
# Country Name        Vietnam
# 2020            271857970.0
# dtype: object

# %%
tp['2020'].mean()
# Out:
# 66864027.8
